# %% [markdown]
# the idea here is that you split ur dataset in two parts . one for training the model ans the other ramaining some for testing the model.

# %%
import pandas as pd
df = pd.read_csv('carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])
plt.show()

# %% [markdown]
# The approach we are going to use here is to split available data in two sets

# %% [markdown]
# 1. Training
# 2. testing

# %% [markdown]
# The reason we don't use same training set for testing is because our model has seen those samples before, using same samples for making predictions might give us wrong impression about accuracy of our model. It is like you ask same questions in exam paper as you tought the students in the class.

# %%
X = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %% [markdown]
# Using train test split

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2) 
#it means we are using 0.2 or 20% of the dataset to test..and the rest to train

# %%
len(X_train)  #16 is used for training out of 20 dataset
# Out:
# 16

# %%
len(X) #total size is 20
# Out:
# 20

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([16018.90512624, 14487.55489048, 34712.87390232, 39036.6863327 ])

# %%
clf.score(X_test,y_test)
# Out:
# 0.9318269417367996

# %% [markdown]
# the model is 93% accurate
